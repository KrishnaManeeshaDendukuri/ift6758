# %% [markdown]
# # 6. Advanced visualisations

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

df = pd.read_csv('tidy_df.csv')

# %%
def transparent_cmap(cmap, N=255):
    "Copy colormap and set alpha values"
    # from https://stackoverflow.com/questions/42481203/heatmap-on-top-of-image

    mycmap = cmap
    mycmap._init()
    mycmap._lut[:,-1] = np.linspace(0, 0.8, N+4)
    return mycmap


#Use base cmap to create transparent
mycmap = transparent_cmap(plt.cm.Reds)

# %%
fig, ax = plt.subplots(figsize= (15,15))

sns.kdeplot(x=df['x_coordinates'][0:10000], y=df['y_coordinates'][0:10000],  cmap=mycmap, shade=True, bw_adjust=.2)
ax.imshow(img, interpolation='nearest', extent = [-100, 100, -42.5, 42.5])
plt.show()
